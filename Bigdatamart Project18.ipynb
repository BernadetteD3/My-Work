# %% [markdown]
# # Bigdatamart Analysis

# %% [markdown]
# # Load and view data

# %%
# Load relevant libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

# %%
# Load data
ds_train=pd.read_csv('bigdatamart_Train.csv')
ds_test=pd.read_csv('bigdatamart_Test.csv')

# %%
ds_train.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
ds_test.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750          Low Fat         0.007565  Snack Foods
# 1           FDW14        8.300              reg         0.038428        Dairy
# 2           NCN55       14.600          Low Fat         0.099575       Others
# 3           FDQ58        7.315          Low Fat         0.015388  Snack Foods
# 4           FDY38          NaN          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007         NaN
# 2  241.7538            OUT010                       1998         NaN
# 3  155.0340            OUT017                       2007         NaN
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type
# 0               Tier 1  Supermarket Type1
# 1               Tier 2  Supermarket Type1
# 2               Tier 3      Grocery Store
# 3               Tier 2  Supermarket Type1
# 4               Tier 3  Supermarket Type3

# %%
ds_train.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %% [markdown]
# Observation: The standard deviation for Item_Outlet_Sales is quite large which might suggest that it will be difficult to predict it accurately.

# %%
ds_train.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
ds_test.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type'],
#       dtype='object')

# %%
ds_train.shape
# Out:
# (8523, 12)

# %%
ds_test.shape
# Out:
# (5681, 11)

# %%
ds_train.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
ds_test.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# dtype: object

# %% [markdown]
# Observation: ds_test does not contain the Item_Outlet_Sales column, it will have to be added later as it will be the target.

# %%
ds_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
ds_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5681 entries, 0 to 5680
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            5681 non-null   object
#  1   Item_Weight                4705 non-null   float64
#  2   Item_Fat_Content           5681 non-null   object
#  3   Item_Visibility            5681 non-null   float64
#  4   Item_Type                  5681 non-null   object
#  5   Item_MRP                   5681 non-null   float64
#  6   Outlet_Identifier          5681 non-null   object
#  7   Outlet_Establishment_Year  5681 non-null   int64
#  8   Outlet_Size                4075 non-null   object
#  9   Outlet_Location_Type       5681 non-null   object
#  10  Outlet_Type                5681 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 488.3+ KB

# %% [markdown]
# # Check and replace null values

# %%
ds_train.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
ds_test.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
ds_train['Item_Weight'].fillna(ds_train['Item_Weight'].median(),inplace=True)

# %%
sns.countplot(ds_train['Outlet_Size'])

# %%
ds_train= ds_train.replace(np.nan, 'Medium', regex=True)

# %%
ds_train.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
ds_train.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998      Medium               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
ds_test['Item_Weight'].fillna(ds_test['Item_Weight'].median(),inplace=True)

# %%
ds_test= ds_test.replace(np.nan, 'Medium', regex=True)

# %%
ds_test.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# dtype: int64

# %% [markdown]
# # Encode categorical data to numerical data with LabelEncoder

# %%
# Change categorical data to numerical data for all categoriacl columns

from sklearn.preprocessing import LabelEncoder

le=LabelEncoder()

# %%
#Train set
cols=['Item_Fat_Content','Item_Type','Outlet_Size', 'Outlet_Location_Type','Outlet_Type']
for col in cols:
    ds_train[col] = le.fit_transform(ds_train[col])

# %%
ds_train.head()
# Out:
#   Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0           FDA15         9.30                 1         0.016047          4
# 1           DRC01         5.92                 2         0.019278         14
# 2           FDN15        17.50                 1         0.016760         10
# 3           FDX07        19.20                 2         0.000000          6
# 4           NCD19         8.93                 1         0.000000          9
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  249.8092            OUT049                       1999            1
# 1   48.2692            OUT018                       2009            1
# 2  141.6180            OUT049                       1999            1
# 3  182.0950            OUT010                       1998            1
# 4   53.8614            OUT013                       1987            0
#
#    Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales
# 0                     0            1          3735.1380
# 1                     2            2           443.4228
# 2                     0            1          2097.2700
# 3                     2            0           732.3800
# 4                     2            1           994.7052

# %%
# Test set
cols=['Item_Fat_Content','Item_Type', 'Outlet_Size', 'Outlet_Location_Type','Outlet_Type']
for col in cols:
    ds_test[col] = le.fit_transform(ds_test[col])

# %%
ds_test.head()
# Out:
#   Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0           FDW58       20.750                 1         0.007565         13
# 1           FDW14        8.300                 4         0.038428          4
# 2           NCN55       14.600                 1         0.099575         11
# 3           FDQ58        7.315                 1         0.015388         13
# 4           FDY38       12.500                 2         0.118599          4
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  107.8622            OUT049                       1999            1
# 1   87.3198            OUT017                       2007            1
# 2  241.7538            OUT010                       1998            1
# 3  155.0340            OUT017                       2007            1
# 4  234.2300            OUT027                       1985            1
#
#    Outlet_Location_Type  Outlet_Type
# 0                     0            1
# 1                     1            1
# 2                     2            0
# 3                     1            1
# 4                     2            3

# %% [markdown]
# # Correct skewness

# %%
ds_train.skew()
# Out:
# Item_Weight                  0.121845
# Item_Fat_Content             0.994824
# Item_Visibility              1.167091
# Item_Type                    0.101655
# Item_MRP                     0.127202
# Outlet_Establishment_Year   -0.396641
# Outlet_Size                 -0.087072
# Outlet_Location_Type        -0.209093
# Outlet_Type                  0.927438
# Item_Outlet_Sales            1.177531
# dtype: float64

# %%
ds_test.skew()
# Out:
# Item_Weight                  0.166489
# Item_Fat_Content             0.999629
# Item_Visibility              1.238312
# Item_Type                    0.096486
# Item_MRP                     0.136182
# Outlet_Establishment_Year   -0.396306
# Outlet_Size                 -0.087108
# Outlet_Location_Type        -0.209049
# Outlet_Type                  0.927446
# dtype: float64

# %%
#Treating using log
trainsk=ds_train.drop(columns=['Item_Identifier','Outlet_Identifier'])
testsk=ds_test.drop(columns=['Item_Identifier','Outlet_Identifier'])

# %%
for col in trainsk.columns:
    if trainsk.skew().loc[col]>0.55:
        trainsk[col]=np.log1p(trainsk[col])
        
for col in testsk.columns:
    if testsk.skew().loc[col]>0.55:
        testsk[col]=np.log1p(testsk[col])

# %%
trainsk.skew()
# Out:
# Item_Weight                  0.121845
# Item_Fat_Content            -0.332843
# Item_Visibility              1.015334
# Item_Type                    0.101655
# Item_MRP                     0.127202
# Outlet_Establishment_Year   -0.396641
# Outlet_Size                 -0.087072
# Outlet_Location_Type        -0.209093
# Outlet_Type                 -0.236040
# Item_Outlet_Sales           -0.882266
# dtype: float64

# %%
testsk.skew()
# Out:
# Item_Weight                  0.166489
# Item_Fat_Content            -0.329520
# Item_Visibility              1.075093
# Item_Type                    0.096486
# Item_MRP                     0.136182
# Outlet_Establishment_Year   -0.396306
# Outlet_Size                 -0.087108
# Outlet_Location_Type        -0.209049
# Outlet_Type                 -0.235685
# dtype: float64

# %% [markdown]
# # Reducing skewness using square root function
# for col in trainsk.columns:
#     if trainsk.skew.loc[col]>0.55:
#         trainsk[col]=np.sqrt(trainsk[col])
# trainsk.skew()
#
# Gives error that loc is not in function

# %% [markdown]
# # Check correlations

# %%
# Check correlation
trainskcor=trainsk.corr()
trainskcor
# Out:
#                            Item_Weight  Item_Fat_Content  Item_Visibility  \
# Item_Weight                   1.000000         -0.015899        -0.014093
# Item_Fat_Content             -0.015899          1.000000         0.033649
# Item_Visibility              -0.014093          0.033649         1.000000
# Item_Type                     0.028038         -0.115934        -0.035995
# Item_MRP                      0.024951          0.002278        -0.000701
# Outlet_Establishment_Year     0.007739         -0.002087        -0.072349
# Outlet_Size                  -0.010536         -0.011713         0.067534
# Outlet_Location_Type          0.001958         -0.006528        -0.027210
# Outlet_Type                  -0.005839         -0.002072        -0.220345
# Item_Outlet_Sales             0.009716          0.007620        -0.188500
#
#                            Item_Type  Item_MRP  Outlet_Establishment_Year  \
# Item_Weight                 0.028038  0.024951                   0.007739
# Item_Fat_Content           -0.115934  0.002278                  -0.002087
# Item_Visibility            -0.035995 -0.000701                  -0.072349
# Item_Type                   1.000000  0.032651                   0.004970
# Item_MRP                    0.032651  1.000000                   0.005020
# Outlet_Establishment_Year   0.004970  0.005020                   1.000000
# Outlet_Size                -0.001859  0.006059                   0.193389
# Outlet_Location_Type        0.003084  0.000232                  -0.089216
# Outlet_Type                 0.003380  0.000053                   0.020071
# Item_Outlet_Sales           0.019914  0.509886                   0.077032
#
#                            Outlet_Size  Outlet_Location_Type  Outlet_Type  \
# Item_Weight                  -0.010536              0.001958    -0.005839
# Item_Fat_Content             -0.011713             -0.006528    -0.002072
# Item_Visibility               0.067534             -0.027210    -0.220345
# Item_Type                    -0.001859              0.003084     0.003380
# Item_MRP                      0.006059              0.000232     0.000053
# Outlet_Establishment_Year     0.193389             -0.089216     0.020071
# Outlet_Size                   1.000000             -0.614311    -0.223204
# Outlet_Location_Type         -0.614311              1.000000     0.389361
# Outlet_Type                  -0.223204              0.389361     1.000000
# Item_Outlet_Sales            -0.122951              0.059030     0.574313
#
#                            Item_Outlet_Sales
# Item_Weight                         0.009716
# Item_Fat_Content                    0.007620
# Item_Visibility                    -0.188500
# Item_Type                           0.019914
# Item_MRP                            0.509886
# Outlet_Establishment_Year           0.077032
# Outlet_Size                        -0.122951
# Outlet_Location_Type                0.059030
# Outlet_Type                         0.574313
# Item_Outlet_Sales                   1.000000

# %%
# Show correlation heatmap
sns.heatmap(trainskcor)

# %%
# Checking pairplots
sns.pairplot(trainsk)
plt.show()

# %% [markdown]
# # Check and remove outliers

# %%
# Show boxplots for all numerical columns, check outliers
collist=trainsk.columns.values
ncol=9
nrows=10

plt.figure(figsize=(ncol,5*ncol))
for i in range(1, len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(trainsk[collist[i]], color='red', orient='v')
    plt.tight_layout()

# %%
#Train set
from scipy.stats import zscore
z_score=abs(zscore(trainsk))
print(trainsk.shape)
ztrainsk=trainsk.loc[(z_score<3).all(axis=1)]
print(ztrainsk.shape)
# Out:
# (8523, 10)
# (8075, 10)

# %%
#Test set
from scipy.stats import zscore
z_score2=abs(zscore(testsk))
print(testsk.shape)
ztestsk=testsk.loc[(z_score2<3).all(axis=1)]
print(ztestsk.shape)
# Out:
# (5681, 9)
# (5410, 9)

# %% [markdown]
# # Linear regression

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.externals import joblib
from sklearn import linear_model
import pickle

# %%
trainsk.columns
# Out:
# Index(['Item_Weight', 'Item_Fat_Content', 'Item_Visibility', 'Item_Type',
#        'Item_MRP', 'Outlet_Establishment_Year', 'Outlet_Size',
#        'Outlet_Location_Type', 'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
trainsk.dtypes
# Out:
# Item_Weight                  float64
# Item_Fat_Content             float64
# Item_Visibility              float64
# Item_Type                      int32
# Item_MRP                     float64
# Outlet_Establishment_Year      int64
# Outlet_Size                    int32
# Outlet_Location_Type           int32
# Outlet_Type                  float64
# Item_Outlet_Sales            float64
# dtype: object

# %%
# Select data to use and target values
nds_x=trainsk.drop(columns=['Item_Outlet_Sales'])
nds_y=trainsk[['Item_Outlet_Sales']]

# %%
#Scaling for linear regression
sc=StandardScaler()
x=sc.fit_transform(nds_x)
x=pd.DataFrame(x,columns=nds_x.columns)

# %%
x.skew()
# Out:
# Item_Weight                  0.121845
# Item_Fat_Content            -0.332843
# Item_Visibility              1.015334
# Item_Type                    0.101655
# Item_MRP                     0.127202
# Outlet_Establishment_Year   -0.396641
# Outlet_Size                 -0.087072
# Outlet_Location_Type        -0.209093
# Outlet_Type                 -0.236040
# dtype: float64

# %%
# Train test split
x_train,x_test, y_train, y_test = train_test_split(x,nds_y, random_state=55, test_size=0.20)

# %%
# Error calculation
max_r_score=0
for r_state in range(42,100):
    x_train,x_test, y_train, y_test = train_test_split(x,nds_y, random_state=r_state, test_size=0.20)
    regr=linear_model.LinearRegression()
    regr.fit(x_train,y_train)
    y_pred=regr.predict(x_test)
    r2_scr=r2_score(y_test,y_pred)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state
print("Max r2 score for",final_r_state,"is", max_r_score)
# Out:
# Max r2 score for 76 is 0.6722608070351668

# %%
# Crossvalidation
cross_val_score(linear_model.LinearRegression(),x,nds_y,cv=10,scoring='r2').mean()
# Out:
# 0.6419428379689381

# %%
# R2 score gives us a rondom state of 76
x_train,x_test, y_train, y_test = train_test_split(x,nds_y, random_state=76, test_size=0.20)
lreg=linear_model.LinearRegression()
lreg.fit(x_train,y_train)
y_pred=lreg.predict(x_test)

# %%
# R2 and Mean squared error statements
print('r score is: ',r2_score(y_test,y_pred))
print('RMSE is: ', np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# r score is:  0.6722608070351668
# RMSE is:  0.588025985648465

# %% [markdown]
# This is not a great score

# %%
#save model as a pickle file
joblib.dump(lreg,'Item_outlet_sales.pkl')
# Out:
# ['Item_outlet_sales.pkl']

# %% [markdown]
# # Load saved model to make predictions with the test data

# %%
lreg_from_joblib=joblib.load('Item_outlet_sales.pkl')

# %%
lreg_from_joblib.predict(testsk)
# Out:
# array([[190.64041285],
#        [180.28310238],
#        [258.18323424],
#        ...,
#        [196.09930079],
#        [245.53208409],
#        [176.08819385]])

# %%
testsk.head()
# Out:
#    Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP  \
# 0       20.750          0.693147         0.007536         13  107.8622
# 1        8.300          1.609438         0.037708          4   87.3198
# 2       14.600          0.693147         0.094924         11  241.7538
# 3        7.315          0.693147         0.015271         13  155.0340
# 4       12.500          1.098612         0.112077          4  234.2300
#
#    Outlet_Establishment_Year  Outlet_Size  Outlet_Location_Type  Outlet_Type
# 0                       1999            1                     0     0.693147
# 1                       2007            1                     1     0.693147
# 2                       1998            1                     2     0.000000
# 3                       2007            1                     1     0.693147
# 4                       1985            1                     2     1.386294

# %% [markdown]
# # Other methods attempted (Classification for regression)
# Gives an error of continious data - please advise

# %%
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
# Perform KNeighbour classification and check it's accuracy
dtc=KNeighborsClassifier()
dtc.fit(x_train,y_train)
dtc.score(x_train,y_train)
preddtc=dtc.predict(x_test)
print(accuracy_score(y_test,preddtc))
print(confusion_matrix(y_test,preddtc))
print(classificatin_report(y_test,preddtc))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-127-cf929ab7356c> in <module>
#       1 # Perform KNeighbour classification and check it's accuracy
#       2 dtc=KNeighborsClassifier()
# ----> 3 dtc.fit(x_train,y_train)
#       4 dtc.score(x_train,y_train)
#       5 preddtc=dtc.predict(x_test)
#
# ~\anaconda3\lib\site-packages\sklearn\neighbors\_base.py in fit(self, X, y)
#    1142             self.outputs_2d_ = True
#    1143
# -> 1144         check_classification_targets(y)
#    1145         self.classes_ = []
#    1146         self._y = np.empty(y.shape, dtype=np.int)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\multiclass.py in check_classification_targets(y)
#     167     if y_type not in ['binary', 'multiclass', 'multiclass-multioutput',
#     168                       'multilabel-indicator', 'multilabel-sequences']:
# --> 169         raise ValueError("Unknown label type: %r" % y_type)
#     170
#     171
#
# ValueError: Unknown label type: 'continuous'

# %%
# Perform Support Vector Machine classification and check it's accuracy
svc=SVC(kernel='linear')
svc.fit(x_train,y_train)
svc.score(x_train,y_train)
print(confusion_matrix(y_test,predsvc))
print(accuracy_score(y_test,predsvc))
print(confusion_matrix(y_test,predsvc))
print(classificatin_report(y_test,predsvc))
